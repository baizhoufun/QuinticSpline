# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
def PolyCoefficients(x, coeffs):
    o = len(coeffs)
    y = 0
    for i in range(o):
        y += coeffs[i]*x**i
    return y

# %%
ar = pd.read_csv("spline.txt",delimiter='\t',header=None).values
ar1 = pd.read_csv("scatter.txt",delimiter='\t',header=None).values
l = (ar.shape[0]+1)/4

fig = plt.figure()
ax = fig.add_subplot(111)
t = np.linspace(0.01, 0.99, 100)

for k in range(0,l-1,1):
    cx = ar[0+k]
    cy = ar[l+k]        
    cz = ar[l+l+k]        
    ax.plot(PolyCoefficients(t,cx),PolyCoefficients(t,cy))        

plt.scatter(ar1[:,0],ar1[:,1])
    
ax.set_aspect('equal','box')
plt.show()

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
 
mpl.rcParams['legend.fontsize'] = 10
 
fig = plt.figure()

ax = fig.gca(projection='3d')
for k in range(0,l-1,1):
    cx = ar[0+k]
    cy = ar[l+k]    
    cz = ar[2*l+k]    
    ax.plot(PolyCoefficients(t,cx),PolyCoefficients(t,cy),PolyCoefficients(t,cz))
    

ax.scatter(ar1[:,0],ar1[:,1],ar1[:,2])
 
plt.show()

# %%
pd.read_csv("spline.txt",delimiter='\t',header=None).values
# Out:
# array([[ 0.00000000e+00,  2.45620943e-01,  0.00000000e+00,
#         -2.27817349e-03, -4.44089210e-16, -3.38324380e-06],
#        [ 2.43339387e-01,  2.33409793e-01, -6.56346275e-03,
#         -2.15978031e-03, -1.54477113e-05, -3.37082340e-06],
#        [ 4.68007118e-01,  2.04236762e-01, -1.20258836e-02,
#         -1.96805325e-03, -2.69365784e-05, -2.65516268e-06],
#        ...,
#        [ 2.36781353e-01,             nan,             nan,
#                     nan,             nan,             nan],
#        [ 2.47781379e-01,             nan,             nan,
#                     nan,             nan,             nan],
#        [ 2.53471103e-01,             nan,             nan,
#                     nan,             nan,             nan]])
